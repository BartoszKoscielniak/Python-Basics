# %% [markdown]
# # Demonstracja biblioteki (pakietu) SQLAlchemy
#
# ### SQLAlchemy to biblioteka programistyczna napisana w języku Python i służąca do realizacji dostępu do relacyjnych baz danych oraz mapowania obiektowo-relacyjnego.
#
# Wspiera takie bazy danych jak: Firebird, Microsoft SQL Server, MySQL, Oracle, PostgreSQL, SQLite oraz Sybase. Głównym jej celem jest wykonywanie zapytań z relacyjnej bazy danych. Jednak wyniki tych zapytań mogą być uzyskane w postaci zbiorów danych biblioteki Pandas (obiekty DataFrame) co powoduje, że z użyciem SQLAlchemy pracujemy tak, jakbyśmy wczytywali dane z plików, choć są pobierane z relacyjnej bazy danych.
#
# Instalacja pakietu SQLAlchemy odbywa sie poleceniem: `pip install SQLAlchemy`
#
# Aby dostawać się do bazy PostgreSQL trzeba zainstalować jeszcze driver: `pip install psycopg2`

# %%
#PIERWSZA metoda dostępu do tabeli bazy danych
#Pobieranie z bazy wszystkich wierszy jednocześnie
#Po wykonaniu zapytania, wszystkie wiersze razem są w pamięci na liście wierszy

#Polecenie usuwa wszystkie zmienne z pamięci 
# %reset -f 

import sqlalchemy as db

#Dane dostępowe do bazy danych
dialect = "postgresql"
driver = "psycopg2"

database = "JUPTEST"

CzyLOKALNIE = False

if CzyLOKALNIE: #Lokalnie
    username = "postgres" 
    password = "polska2019"
    host = "localhost"
    port = "5432"
else: #Odlegly    
    username = "student" 
    password = "s#x$a2!s3y4"    
    host = "localhost"    
    port = "5433" #Inny port

    
    
engine = db.create_engine(dialect+"+"+driver+"://"+username+":"+password+"@"+host+":"+port+"/"+database)

query = "select * from SERCE limit 3"

rp = engine.execute(query)

columns = rp.keys() #Pobranie informacji o kolumnach 
print("Kolumny:",columns)

rows = rp.fetchall() #Pobranie wszystkich wierszy od razu

#Przegladanie wierszy
for row in rows:    
    i = 0
    text = ''
    #Przeglądanie kolumn w wierszu
    while i < len(row):
        value = str(row[i])
        text = text + str(value)
        if i<len(row)-1: text = text + "|"
        i = i + 1
    print(text)
# Out:
# Kolumny: RMKeyView(['wiek', 'plec', 'typ_bolu_klatka', 'cisnienie_krwi_spoczynek', 'cholesterol_we_krwi', 'cukier_we_krwi', 'wynik_ekg_spoczynek', 'ilosc_uderzen_serca', 'bol_klatka_wysilek', 'max_obnizka_st', 'przebieg_st_szczyt', 'zwapnienia_miazdzycowe', 'proba_ta', 'diagnoza'])
# 70.0|1.0|4.0|130.0|322.0|0.0|2.0|109.0|0.0|2.4|2.0|3.0|3.0|2
# 67.0|0.0|3.0|115.0|564.0|0.0|2.0|160.0|0.0|1.6|2.0|0.0|7.0|1
# 57.0|1.0|2.0|124.0|261.0|0.0|0.0|141.0|0.0|0.3|1.0|0.0|7.0|2

# %%
#DRUGA metoda dostępu do tabeli bazy danych
#Pobieranie wierszy z bazy jeden po drugim, co jest bardziej efektywne pamięciowo
#Tylko jeden wiersz jest jednocześnie w pamięci (STOSUJE SIĘ DLA DUŻYCH DANYCH)

#Polecenie usuwa wszystkie zmienne z pamięci 
# %reset -f 

import pandas as pd
import sqlalchemy as db

#Dane dostępowe do bazy danych
dialect = "postgresql"
driver = "psycopg2"

database = "JUPTEST"

CzyLOKALNIE = False

if CzyLOKALNIE: #Lokalnie
    username = "postgres" 
    password = "polska2019"
    host = "localhost"
    port = "5432"
else: #Odlegly    
    username = "student" 
    password = "s#x$a2!s3y4"    
    host = "localhost"    
    port = "5433" #Inny port

    
    
engine = db.create_engine(dialect+"+"+driver+"://"+username+":"+password+"@"+host+":"+port+"/"+database)

query = "select * from SERCE limit 4"

rp = engine.execute(query)

columns = rp.keys() #Pobranie informacji o kolumnach 
print("Kolumny:",columns)

while (True):
    row = rp.fetchone() #Pobranie jednego wiersza (zwaracana jest tuple)    
    if row is None: break
    text = ''
    i = 0
    #Przeglądanie kolumn w wierszu
    while i < len(row):
        value = str(row[i])
        text = text + str(value)
        if i<len(row)-1: text = text + "|"
        i = i + 1
    print(text)
# Out:
# Kolumny: RMKeyView(['wiek', 'plec', 'typ_bolu_klatka', 'cisnienie_krwi_spoczynek', 'cholesterol_we_krwi', 'cukier_we_krwi', 'wynik_ekg_spoczynek', 'ilosc_uderzen_serca', 'bol_klatka_wysilek', 'max_obnizka_st', 'przebieg_st_szczyt', 'zwapnienia_miazdzycowe', 'proba_ta', 'diagnoza'])
# 70.0|1.0|4.0|130.0|322.0|0.0|2.0|109.0|0.0|2.4|2.0|3.0|3.0|2
# 67.0|0.0|3.0|115.0|564.0|0.0|2.0|160.0|0.0|1.6|2.0|0.0|7.0|1
# 57.0|1.0|2.0|124.0|261.0|0.0|0.0|141.0|0.0|0.3|1.0|0.0|7.0|2
# 64.0|1.0|4.0|128.0|263.0|0.0|0.0|105.0|1.0|0.2|2.0|1.0|7.0|1

# %%
#TRZECIA metoda dostępu do tabeli bazy danych
#Pobieranie z bazy obiektu DataFrame z wynikami zapytania
#Jest to wygodne, ale potrzeba dużo pamięci RAM na całość danych

#Polecenie usuwa wszystkie zmienne z pamięci 
# %reset -f 

import pandas as pd
import sqlalchemy as db

#Dane dostępowe do bazy danych
dialect = "postgresql"
driver = "psycopg2"
username = "postgres" 


#TRZECIA metoda dostępu do tabeli bazy danych
#Pobieranie z bazy obiektu DataFrame z wynikami zapytania
#Jest to wygodne, ale potrzeba dużo pamięci RAM na całość danych

#Polecenie usuwa wszystkie zmienne z pamięci 
# %reset -f 

import pandas as pd
import sqlalchemy as db

#Dane dostępowe do bazy danych
dialect = "postgresql"
driver = "psycopg2"

database = "JUPTEST"

CzyLOKALNIE = False

if CzyLOKALNIE: #Lokalnie
    username = "postgres" 
    password = "polska2019"
    host = "localhost"
    port = "5432"
else: #Odlegly    
    username = "student" 
    password = "s#x$a2!s3y4"    
    host = "localhost"    
    port = "5433" #Inny port
    

    
engine = db.create_engine(dialect+"+"+driver+"://"+username+":"+password+"@"+host+":"+port+"/"+database)

query = "select * from SERCE limit 5"

dataset = pd.read_sql(sql=query, con=engine)

print("Tablica danych:");
print(dataset)

    
engine = db.create_engine(dialect+"+"+driver+"://"+username+":"+password+"@"+host+":"+port+"/"+database)

query = "select * from SERCE limit 5"

dataset = pd.read_sql(sql=query, con=engine)

print("Tablica danych:");
print(dataset)
# Out:
# Tablica danych:
#    wiek  plec  typ_bolu_klatka  cisnienie_krwi_spoczynek  cholesterol_we_krwi  \
# 0  70.0   1.0              4.0                     130.0                322.0
# 1  67.0   0.0              3.0                     115.0                564.0
# 2  57.0   1.0              2.0                     124.0                261.0
# 3  64.0   1.0              4.0                     128.0                263.0
# 4  74.0   0.0              2.0                     120.0                269.0
#
#    cukier_we_krwi  wynik_ekg_spoczynek  ilosc_uderzen_serca  \
# 0             0.0                  2.0                109.0
# 1             0.0                  2.0                160.0
# 2             0.0                  0.0                141.0
# 3             0.0                  0.0                105.0
# 4             0.0                  2.0                121.0
#
#    bol_klatka_wysilek  max_obnizka_st  przebieg_st_szczyt  \
# ...

# %%
#CZWARTA metoda dostępu do tabeli bazy danych
#Pobieranie z bazy obiektu DataFrame z wynikami zapytania ale nie od razu, tylko w częściach (porcja wierszy)
#Tylko jedna część jest jednocześnie w pamięci (DOBRE DLA DUŻYCH DANYCH)

#Polecenie usuwa wszystkie zmienne z pamięci 
# %reset -f 

import pandas as pd
import sqlalchemy as db

#Dane dostępowe do bazy danych
dialect = "postgresql"
driver = "psycopg2"
username = "postgres" 


#TRZECIA metoda dostępu do tabeli bazy danych
#Pobieranie z bazy obiektu DataFrame z wynikami zapytania
#Jest to wygodne, ale potrzeba dużo pamięci RAM na całość danych

#Polecenie usuwa wszystkie zmienne z pamięci 
# %reset -f 

import pandas as pd
import sqlalchemy as db

#Dane dostępowe do bazy danych
dialect = "postgresql"
driver = "psycopg2"

database = "JUPTEST"

CzyLOKALNIE = False

if CzyLOKALNIE: #Lokalnie
    username = "postgres" 
    password = "polska2019"
    host = "localhost"
    port = "5432"
else: #Odlegly    
    username = "student" 
    password = "s#x$a2!s3y4"    
    host = "localhost"    
    port = "5433" #Inny port

    
engine = db.create_engine(dialect+"+"+driver+"://"+username+":"+password+"@"+host+":"+port+"/"+database)

query = "select * from SERCE limit 5"

dataset = pd.read_sql(sql=query, con=engine)

print("Tablica danych:");
print(dataset)


engine = db.create_engine(dialect+"+"+driver+"://"+username+":"+password+"@"+host+":"+port+"/"+database)

query = "select * from SERCE"

part_size = 50
i = 1
for part in pd.read_sql_query(query , engine, chunksize=part_size):
    print("Dostęp do części tablicy numer:",i)
    #print(part) #Wypisanie aktualnej częśći   
    i = i + 1
    
    if i>5: break #Tylko 5 pierwszych części
# Out:
# Tablica danych:
#    wiek  plec  typ_bolu_klatka  cisnienie_krwi_spoczynek  cholesterol_we_krwi  \
# 0  70.0   1.0              4.0                     130.0                322.0
# 1  67.0   0.0              3.0                     115.0                564.0
# 2  57.0   1.0              2.0                     124.0                261.0
# 3  64.0   1.0              4.0                     128.0                263.0
# 4  74.0   0.0              2.0                     120.0                269.0
#
#    cukier_we_krwi  wynik_ekg_spoczynek  ilosc_uderzen_serca  \
# 0             0.0                  2.0                109.0
# 1             0.0                  2.0                160.0
# 2             0.0                  0.0                141.0
# 3             0.0                  0.0                105.0
# 4             0.0                  2.0                121.0
#
#    bol_klatka_wysilek  max_obnizka_st  przebieg_st_szczyt  \
# ...

# %%
#Zad 1. Wykorzystując pierwszą i drugą metodę dostępu do bazy danych opisane wyżej, napisz program który dokonuje 
#podstawowej analizy statystycznej tabel SERCE i DSERCE w bazie JUPTEST
#(liczba wierszy, liczba kolumn, nazwy kolumn, typy wartości w kolumnach, liczba wartości w kolumnach, 
#liczba pustych miejsc w tablicy). 
#Dla analizy tabeli SERCE użyć pierwszą metodę dostępu do bazy danych opisaną wyżej. Natomiast dla analizy
#tabeli DSERCE użyć 2 metodę dostępu do bazy danych.
#Porównaj uzyskane wyniki dla obydwu tabel zestawiając je ze sobą. Czy bardzo różnią się między sobą?
#Wyniki i odpowiednie wnioski zapisać w komentarzu na końcu komórki z rozwiązaniem.

#Polecenie usuwa wszystkie zmienne z pamięci

# %reset -f

import sqlalchemy as db
import psycopg2
import pandas as pd

#Dane dostępowe do bazy danych
dialect = "postgresql"
driver = "psycopg2"

database = "JUPTEST"

CzyLOKALNIE = False

if CzyLOKALNIE: #Lokalnie
    username = "postgres"
    password = "polska2019"
    host = "localhost"
    port = "5432"
else: #Odlegly
    username = "student"
    password = "s#x$a2!s3y4"
    host = "localhost"
    port = "5433" #Inny port

engine = db.create_engine(dialect+"+"+driver+"://"+username+":"+password+"@"+host+":"+port+"/"+database)

query = "select * from SERCE"

rp = engine.execute(query)

columns = rp.keys()
rows = rp.fetchall()

num_rows = len(rows)
df = pd.DataFrame(rows)
column_types = df.dtypes.iloc[0]
column_value_counts = [len(set(row)) for row in zip(*rows)]
num_empty_values = count = len(rows[rows==(0.0)])

print("SERCE:")
print("Liczba wierszy:", num_rows)
print("Liczba kolumn:", len(columns))
print("Nazwy kolumn:", columns)
print("Typy wartości w kolumnach:", column_types)
print("Liczba wartości w kolumnach:", len(column_value_counts))
print("Liczba pustych miejsc w tablicy:", num_empty_values)

query = "select * from DSERCE limit 5000"

rp = engine.execute(query)

print()
columns = rp.keys()

num_rows = 0
num_empty_values = 0
column_value_counts = 0
column_types = None
while (True):
    row = rp.fetchone()
    if row is None: break
    text = ''
    i = 0
    if column_types == None:
        df = pd.DataFrame(rows)
        column_types = df.dtypes.iloc[0]
        
    if column_value_counts == 0:
        column_value_counts = len(row)
    empty_row = True
    num_rows += 1
    while i < len(row):
        value = str(row[i])
        text = text + str(value)
        if i<len(row)-1: text = text + "|"
        if row[i] != 0.0:
            empty_row = False
        i = i + 1
    if empty_row == True:
        num_empty_values += 1
    
    

print("DSERCE:")
print("Liczba wierszy:", num_rows)
print("Liczba kolumn:", len(columns))
print("Nazwy kolumn:",columns)
print("Typy wartości w kolumnach:", column_types)
print("Liczba wartości w kolumnach:", column_value_counts)
print("Liczba pustych miejsc w tablicy:", num_empty_values)
#Na podstawie danych mozna wywnioskowac ze badane dane maja identyczne cechy za wyjatkiem liczby pustych miejsc w tablicy
# Out:
# SERCE:
# Liczba wierszy: 270
# Liczba kolumn: 14
# Nazwy kolumn: ['wiek', 'plec', 'typ_bolu_klatka', 'cisnienie_krwi_spoczynek', 'cholesterol_we_krwi', 'cukier_we_krwi', 'wynik_ekg_spoczynek', 'ilosc_uderzen_serca', 'bol_klatka_wysilek', 'max_obnizka_st', 'przebieg_st_szczyt', 'zwapnienia_miazdzycowe', 'proba_ta', 'diagnoza']
# Typy wartości w kolumnach: float64
# Liczba wartości w kolumnach: 14
# Liczba pustych miejsc w tablicy: 14
#
# DSERCE:
# Liczba wierszy: 5000
# Liczba kolumn: 14
# Nazwy kolumn: ['wiek', 'plec', 'typ_bolu_klatka', 'cisnienie_krwi_spoczynek', 'cholesterol_we_krwi', 'cukier_we_krwi', 'wynik_ekg_spoczynek', 'ilosc_uderzen_serca', 'bol_klatka_wysilek', 'max_obnizka_st', 'przebieg_st_szczyt', 'zwapnienia_miazdzycowe', 'proba_ta', 'diagnoza']
# Typy wartości w kolumnach: float64
# Liczba wartości w kolumnach: 14
# Liczba pustych miejsc w tablicy: 0

# %%
#Zad 2. Wykorzystując trzecią i czwartą metodę dostępu do bazy danych opisane wyżej, napisz program który dokonuje 
#podstawowej analizy statystycznej tabel REZYGNACJE i DREZYGNACJE w bazie JUPTEST 
#(liczba wierszy, liczba kolumn, nazwy kolumn, typy wartości w kolumnach, liczba wartości w kolumnach, 
#liczba pustych miejsc w tablicy). 
#Dla analizy tabeli REZYGNACJE użyć trzecią metodę dostępu do bazy danych opisaną wyżej. Natomiast dla analizy
#tabeli DREZYGNACJE użyć czwartą metodę dostępu do bazy danych.
#Porównaj uzyskane wyniki dla obydwu tabel zestawiając je ze sobą. Czy bardzo różnią się między sobą?
#Wyniki i odpowiednie wnioski zapisać w komentarzu na końcu komórki z rozwiązaniem.

# %reset -f

import pandas as pd
import sqlalchemy as db
import psycopg2

#Dane dostępowe do bazy danych
dialect = "postgresql"
driver = "psycopg2"
username = "postgres"


#TRZECIA metoda dostępu do tabeli bazy danych
#Pobieranie z bazy obiektu DataFrame z wynikami zapytania
#Jest to wygodne, ale potrzeba dużo pamięci RAM na całość danych

#Polecenie usuwa wszystkie zmienne z pamięci
# %reset -f

import pandas as pd
import sqlalchemy as db

#Dane dostępowe do bazy danych
dialect = "postgresql"
driver = "psycopg2"

database = "JUPTEST"

CzyLOKALNIE = False

if CzyLOKALNIE: #Lokalnie
    username = "postgres"
    password = "polska2019"
    host = "localhost"
    port = "5432"
else: #Odlegly
    username = "student"
    password = "s#x$a2!s3y4"
    host = "localhost"
    port = "5433" #Inny port

engine = db.create_engine(dialect+"+"+driver+"://"+username+":"+password+"@"+host+":"+port+"/"+database)

query = "select * from REZYGNACJE limit 5"

dataset = pd.read_sql(sql=query, con=engine)

'''num_rows = len(rows)
df = pd.DataFrame(rows)
column_types = df.dtypes.iloc[0]
column_value_counts = [len(set(row)) for row in zip(*rows)]
num_empty_values = count = len(rows[rows==(0.0)])'''

print("REZYGNACJE:")
print("Liczba wierszy:", dataset.shape[0])
print("Liczba kolumn:", dataset.shape[1])
print("Nazwy kolumn:", dataset.columns)
print("Typy wartości w kolumnach:", dataset.dtypes)
print("Liczba wartości w kolumnach:", dataset.count())
print("Liczba pustych miejsc w tablicy:", dataset.isnull().sum())

query = "select * from DREZYGNACJE limit 5000"

part_size = 50
i = 1
row_count = 0
row_column = 0
columns_values = 0
empty_spaces = 0
for part in pd.read_sql_query(query , engine, chunksize=part_size):
    print("Dostęp do części tablicy numer:",i)
    #print(part) #Wypisanie aktualnej częśći
    i = i + 1
    row_count +=  dataset.shape[0]
    row_column += dataset.shape[1]
    columns_values += dataset.count()
    empty_spaces += dataset.isnull().sum()
    if i>5: break #Tylko 5 pierwszych części
        
print()
print("DREZYGNACJE:")
print("Liczba wierszy:", row_count)
print("Liczba kolumn:", row_column)
print("Nazwy kolumn:", part.columns)
print("Typy wartości w kolumnach:", part.dtypes)
print("Liczba wartości w kolumnach:", columns_values)
print("Liczba pustych miejsc w tablicy:", empty_spaces)
# Out:
# REZYGNACJE:
# Liczba wierszy: 5
# Liczba kolumn: 21
# Nazwy kolumn: Index(['stan', 'czas_posiadania', 'kod_obszaru', 'nr_tel', 'plan_miedzy',
#        'poczta_g', 'l_wiad_poczta_g', 'dzien_min', 'dzien_l_pol',
#        'dzien_oplata', 'wieczor_min', 'wiecz_l_pol', 'wiecz_oplata', 'noc_min',
#        'noc_l_pol', 'noc_oplata', 'miedzy_min', 'miedzy_l_pol',
#        'miedzy_oplata', 'l_pol_biuro', 'rezygn'],
#       dtype='object')
# Typy wartości w kolumnach: stan                object
# czas_posiadania      int64
# kod_obszaru          int64
# nr_tel              object
# plan_miedzy          int64
# poczta_g             int64
# l_wiad_poczta_g      int64
# dzien_min          float64
# dzien_l_pol        float64
# dzien_oplata       float64
# wieczor_min        float64
# wiecz_l_pol          int64
# wiecz_oplata       float64
# noc_min            float64
# noc_l_pol            int64
# noc_oplata         float64
# miedzy_min         float64
# miedzy_l_pol         int64
# ...
